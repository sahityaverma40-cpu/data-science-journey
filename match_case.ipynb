# %%
code = 200
match code:
    case 200:
        print("Response is Ok")
    case 400:
        print("Bad Request")
    case 404:
        print("Not Found")
    case _:
        print("Unknown Error")
# Out:
# Response is Ok
