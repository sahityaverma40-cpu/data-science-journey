# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# Union – combines all unique elements
print(set1 | set2)            # {1, 2, 3, 4, 5, 6}
print(set1.union(set2))       # same result

# Intersection – common elements
print(set1 & set2)            # {3, 4}
print(set1.intersection(set2))# same result

# Difference – in set1 but not in set2
print(set1 - set2)            # {1, 2}
print(set1.difference(set2))  # same result

# Symmetric Difference – in either set, but not both
print(set1 ^ set2)                     # {1, 2, 5, 6}
print(set1.symmetric_difference(set2))# same result
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {3, 4}
# {1, 2}
# {1, 2}
# {1, 2, 5, 6}
# {1, 2, 5, 6}

# %%
set1 = {22,33,43,45,34,545,}

# %%
set1
# Out:
# {22, 33, 34, 43, 45, 545}

# %%
# add new elements to the existing set1 and display the result
set1.update({32, 453, 435, 5353, 42, 4})
set1
# Out:
# {4, 22, 32, 33, 34, 42, 43, 45, 435, 453, 545, 5353}

# %%
set2 = {3, 4,55,22,43,54,45}
set2
# Out:
# {3, 4, 22, 43, 45, 54, 55}

# %%
# compute and display the union of set1 and set2
set1.union(set2)
# Out:
# {3, 4, 22, 32, 33, 34, 42, 43, 45, 54, 55, 435, 453, 545, 5353}
