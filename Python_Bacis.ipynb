# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Sahitya"

# %%
print("Hello Sahitya")
# Out:
# Hello Sahitya

# %%
# this is comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
x = 10
y = 10.2
z = "Sahitya"
Sahitya = True

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
print(type(Sahitya))
# Out:
# <class 'bool'>
